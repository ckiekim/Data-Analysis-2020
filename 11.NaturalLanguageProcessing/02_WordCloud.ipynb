# %% [markdown]
# # 워드 클라우드

# %% [markdown]
# ### 설치
# #### - conda install -c conda-forge wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib as mpl 
import matplotlib.pyplot as plt 
# %matplotlib inline
# 한글폰트 사용
mpl.rc('font', family='Malgun Gothic')
mpl.rc('axes', unicode_minus=False)

# %% [markdown]
# ### Alice in Wonderland

# %%
text = open('./data/Alice.txt').read()
stopwords = set(STOPWORDS)
stopwords.add('said')

# %%
print(stopwords)
# Out:
# {"where's", 'those', 'than', "he'll", 'herself', 'a', 'also', "here's", 'http', "we've", 'itself', "we'll", 'an', "they'll", "shan't", 'were', "isn't", 'could', 'both', 'nor', 'com', 'cannot', 'their', 'on', 'doing', 'his', 'so', 'where', 'with', "shouldn't", 'themselves', "how's", "when's", "don't", 'into', 'through', 'we', 'why', 'yours', 'up', 'between', 'very', 'did', 'own', "he'd", "aren't", 'again', "they'd", 'this', 'my', 'when', 'no', "who's", "i've", 'therefore', 'during', "weren't", 'while', "couldn't", 'he', "they've", "you're", 'before', 'too', 'until', 'below', 'hence', 'what', 'does', 'over', 'most', 'ourselves', 'if', 'me', 'the', 'myself', "hasn't", 'for', 'would', 'your', "you'd", 'by', 'which', 'after', 'or', 'yourselves', 'that', 'then', 'has', "why's", 'to', 'such', 'she', 'her', 'him', "mustn't", 'who', 'them', "doesn't", 'only', 'once', "didn't", "it's", 'ever', "hadn't", 'these', 'whom', 'himself', "she's", 'yourself', 'under', 'down', "i'm", "can't", "she'd", "haven't", 'about', 'had', "we'd", 'www', 'do', "we're", 'you', 'however', "let's", 'further', 'they', 'said', 'am', 'each', "she'll", 'being', "he's", 'having', 'any', 'ought', 'ours', 'have', 'not', 'other', 'same', 'it', 'k', 'off', 'from', 'just', 'our', 'since', "what's", 'r', 'as', 'is', 'at', 'more', 'shall', 'few', 'theirs', 'but', 'against', 'and', 'because', 'all', "there's", "wasn't", 'here', "wouldn't", 'there', 'else', 'be', 'been', 'like', 'otherwise', 'above', 'i', "that's", 'are', "they're", 'should', 'out', 'get', "you've", 'how', 'of', "i'd", 'was', 'its', 'in', 'can', 'some', "you'll", "i'll", "won't", 'hers'}

# %%
wc = WordCloud(background_color='white', max_words=2000, stopwords=stopwords)
wc = wc.generate(text)

# %%
keys = list(wc.words_.keys())
values = list(wc.words_.values())
for i in range(10):
    print(f'{keys[i]}: {values[i]}')
# Out:
# Alice: 1.0
# little: 0.29508196721311475
# one: 0.27595628415300544
# know: 0.2459016393442623
# went: 0.226775956284153
# thing: 0.2185792349726776
# time: 0.2103825136612022
# Queen: 0.20765027322404372
# see: 0.1830601092896175
# King: 0.17486338797814208

# %%
plt.figure(figsize=(12,6))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# #### 그림에 표시하기

# %%
mask = np.array(Image.open('./data/Alice_mask.png'))

plt.figure(figsize=(8,8))
plt.imshow(mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
wc = WordCloud(background_color='white', max_words=2000, mask=mask, stopwords=stopwords)
wc = wc.generate(text)

# %%
plt.figure(figsize=(8,8))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ### Star Wars - A New Hope

# %%
text = open('./data/A_new_hope.txt').read()
text = text.replace('HAN', 'Han')
text = text.replace("LUKE'S", 'Luke')

mask = np.array(Image.open('./data/Stormtrooper_mask.png'))

# %%
stopwords = set(STOPWORDS)
stopwords.add('int')
stopwords.add('ext')

# %%
wc = WordCloud(max_words=1000, mask=mask, stopwords=stopwords,
               margin=10, random_state=1).generate(text)
default_colors = wc.to_array()

# %%
import random
def grey_color(word, font_size, position, orientation,
               random_state=None, **kwargs):
    return 'hsl(0, 0%%, %d%%)' % random.randint(60,100)     # hue, saturation, lightness

# %%
plt.figure(figsize=(12,12))
plt.imshow(wc.recolor(color_func=grey_color, random_state=3), interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
keys = list(wc.words_.keys())
values = list(wc.words_.values())
for i in range(10):
    print(f'{keys[i]}: {values[i]}')
# Out:
# Luke: 1.0
# Han: 0.45121951219512196
# DEATH STAR: 0.3902439024390244
# THREEPIO: 0.36585365853658536
# Ben: 0.2665505226480836
# Leia: 0.19686411149825783
# ship: 0.19686411149825783
# Artoo: 0.17247386759581881
# one: 0.1672473867595819
# X WING: 0.16550522648083624
